# %%
from search import *
from game import *
from util import *
from pacman import *
import util, layout
import sys, types, time, random, os
import numpy as np
from random import random, randint, seed, choice

import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# %%
# tiny genetic programming by © moshe sipper, www.moshesipper.com

from statistics import mean
from copy import deepcopy

POP_SIZE        = 60   # population size
MIN_DEPTH       = 2    # minimal initial random tree depth
MAX_DEPTH       = 5    # maximal initial random tree depth
GENERATIONS     = 250  # maximal number of generations to run evolution
TOURNAMENT_SIZE = 5    # size of tournament for tournament selection
XO_RATE         = 0.8  # crossover rate 
PROB_MUTATION   = 0.2  # per-node mutation probability 



def add(x, y): return x + y
def sub(x, y): return x - y
def mul(x, y): return x * y

"FUNCOES ( sao as operacoes executadas nos nós das arvores)-> add, sub, mul, div (x/0 = 1)*"
"TERMINAIS ( sao os tipos possiveis de nohs folha )"
'''
    TERMINAIS ( sao os tipos possiveis de nohs folha )
        -> GAMESTATE_X, onde 0 <= X < Num. de variaveis de estado do jogo
        -> CONSTANTS ( Uns numeros constantes para algumas operações, para facilitar o calculo numerico (?) )
        
    
'''




FUNCTIONS = [add, sub, mul]
TERMINALS = ['actionScore', 
             'eatFood', 
             'minGhostDist', 
             'minDistToFood', 
             'distToPill', 
             'minDistEdibleGhost', 
             'encounterGhost',
             -1.0, 0.5, 1.0, 2.0] # 0.0,  -0.5,

STATE_VARS = ['actionScore', 'eatFood', 'minGhostDist', 'minDistToFood', 'distToPill', 'minDistEdibleGhost', 'encounterGhost']
" actionScore: scoreFuturo - scoreAtual "
" eatFood: numFoodAtual - numFoodFuturo"
" minGhostDist: |ghostX - pacmanX| + |ghostY - pacmanY| "
" minDistToFood: |foodX - pacmanX| + |foodY - pacmanY| "
" distToPill: |pillX - pacmanX| + |pillY - pacmanY| "


class GPTree:
    def __init__(self, data = None, left = None, right = None):
        self.data  = data
        self.left  = left
        self.right = right
        
    def setLeft(self, tree):
        self.left = tree
        
    def setRight(self, tree):
        self.right = tree
        
    def node_label(self): # string label
        if (self.data in FUNCTIONS):
            return self.data.__name__
        else: 
            return str(self.data)
    
    def print_tree(self, prefix = ""): # textual printout
        print("%s%s" % (prefix, self.node_label()))        
        if self.left:  self.left.print_tree (prefix + "   ")
        if self.right: self.right.print_tree(prefix + "   ")

    def computeTree(self, stateVars): 
        if (self.data in FUNCTIONS): 
            return self.data(self.left.computeTree(stateVars), self.right.computeTree(stateVars))
        elif (self.data in STATE_VARS): 
            return stateVars[self.data]
        else: return self.data
        
    def size(self): # tree size in nodes
        if self.data in TERMINALS: return 1
        l = self.left.size()  if self.left  else 0
        r = self.right.size() if self.right else 0
        return 1 + l + r
    
    def random_tree(self, grow, max_depth, depth = 0): # create random tree using either grow or full method
        if depth < MIN_DEPTH or (depth < max_depth and not grow): 
            self.data = FUNCTIONS[randint(0, len(FUNCTIONS)-1)]
        elif depth >= max_depth:   
            self.data = TERMINALS[randint(0, len(TERMINALS)-1)]
        else: # intermediate depth, grow
            if random () > 0.5: 
                self.data = TERMINALS[randint(0, len(TERMINALS)-1)]
            else:
                self.data = FUNCTIONS[randint(0, len(FUNCTIONS)-1)]
        if self.data in FUNCTIONS:
            self.left = GPTree()          
            self.left.random_tree(grow, max_depth, depth = depth + 1)            
            self.right = GPTree()
            self.right.random_tree(grow, max_depth, depth = depth + 1)
            
    def getSubtree(self):
        t = GPTree()
        t.data = self.data
        if self.left:  t.left  = self.left.getSubtree()
        if self.right: t.right = self.right.getSubtree()
        return t
    
    def scan_tree(self, count, second): # note: count is list, so it's passed "by reference"
        count[0] -= 1            
        if count[0] <= 1: 
            if not second: # return subtree rooted here
                return self.getSubtree()
            else: # glue subtree here
                self.data  = second.data
                self.left  = second.left
                self.right = second.right
        else:  
            ret = None              
            if self.left  and count[0] > 1: ret = self.left.scan_tree(count, second)  
            if self.right and count[0] > 1: ret = self.right.scan_tree(count, second)  
            return ret
        
    def mutation(self, probability=0.75):
        if random() < probability: # mutate at this node
            self.random_tree(grow = True, max_depth = 2)
        elif self.left: self.left.mutation(probability)
        elif self.right: self.right.mutation(probability)

# %%
tree = GPTree()
tree.random_tree(True, 2)
tree.print_tree()
thisdict = {
    STATE_VARS[0]: 1.0,
    STATE_VARS[1]: 2.0,
    STATE_VARS[2]: 3.0,
    STATE_VARS[3]: 4.0,
    STATE_VARS[4]: 5.0,
    STATE_VARS[5]: 6.0,
    STATE_VARS[6]: 7.0
}
print(tree.computeTree(thisdict))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-358ac09ce746> in <module>
# ----> 1 tree = GPTree()
#       2 tree.random_tree(True, 2)
#       3 tree.print_tree()
#       4 thisdict = {
#       5     STATE_VARS[0]: 1.0,
#
# NameError: name 'GPTree' is not defined

# %%
" Criar populacao inicial"
''' Para a criação da população inicial, utilizamos o método RandomTree() que gera árvores randomicamente dentro 
    do domínio de operações fundamentais (add, sub, mul) 
        e dos terminais definidos (variaveis de estado e constantes)
'''
# Out:
# ' Para a criação da população inicial, utilizamos o método RandomTree() que gera árvores randomicamente dentro \n    do domínio de operações fundamentais (add, sub, mul) \n        e dos terminais definidos (variaveis de estado e constantes)\n'

# %%
def initialPopulation(populationSize=32,treeDepth=3):
    population = []
    for _ in range(populationSize):
        tree = GPTree()
        tree.random_tree(True, treeDepth)
        population.append(tree)
    return population

# %%
" FITNESS "

# stateVars -> dictionary  ex stateVars['distX'] = distXGameStateVariable
def getFitness(individuo, gen):
    return trainIndividual(individuo, gen)

def getPopFitness(population, gen):
    return [getFitness(population[i], gen) for i in range(0,len(population))]

    
    

" SELEÇÂO "
'''Para algotimo de seleção, adotaremos inicialmente o método de seleção por Torneio, na ideia de
    aumentar as randomicidade do modelo.
'''
def tournament(population, fitness, size):
    indexes = np.random.choice(range(0,len(population)),size,False)
    chosen = [fitness[i] for i in indexes]
    return population[indexes[chosen.index(max(chosen))]]

def getParent(population, fitness,size=4):
    return tournament(population, fitness, size)


" CROSSOVER "
''' Para a reprodução dos pais, utilizamos uma função de crossover para árvores, 
'''

def crossover(treeA, treeB): # xo 2 trees at random nodes
    if random() < XO_RATE:
        geneA = treeA.scan_tree([randint(1, treeA.size())], None) # 1st random subtree
        geneB = treeB.scan_tree([randint(1, treeB.size())], None) # 2nd random subtree
        treeA.scan_tree([randint(1, treeA.size())], geneB) # 2nd subtree "glued" inside 1st tree
        treeB.scan_tree([randint(1, treeB.size())], geneA) # 1st subtree "glued" inside 2nd tree
        
#    child1 = treeA.getSubtree()
#    child2 = treeB.getSubtree()
    
#    aux = child1.right.getSubtree()
#    aux.print_tree()
#    child1.right = child2.left.getSubtree()
#    child2.left = aux
    
    return treeA, treeB
    
            
" Loop de Reproducao"
# Out:
# ' Loop de Reproducao'

# %%
tree = GPTree()
tree.random_tree(True, 3)
tree.print_tree()

tree2 = GPTree()
tree2.random_tree(True, 3)
tree2.print_tree()

c1, c2 = crossover(tree, tree2)
c1.print_tree()
c2.print_tree()
# Out:
# sub
#    mul
#       sub
#          minDistEdibleGhost
#          0.5
#       minDistToFood
#    sub
#       mul
#          minGhostDist
#          minGhostDist
#       sub
#          -1.0
#          eatFood
# sub
#    mul
#       add
#          -1.0
#          minGhostDist
#       add
#          eatFood
#          minGhostDist
#    add
#       0.5
#       2.0
# sub
#    mul
#       sub
#          minDistEdibleGhost
#          0.5
#       minDistToFood
#    sub
#       mul
#          minGhostDist
#          minGhostDist
#       sub
#          -1.0
#          eatFood
# sub
#    mul
#       add
#          -1.0
#          minGhostDist
#       add
#          eatFood
#          minGhostDist
#    add
#       0.5
#       2.0

# %%
n = Directions.NORTH
s = Directions.SOUTH
e = Directions.EAST
w = Directions.WEST

def manhattanDistance(posA, posB):
    return (abs(posB[0] - posA[0]) + abs(posB[1] - posA[1]))

def calcMinGhostDist(pacmanPosition, ghostsPosition):
    dist = 99999
    for ghost in ghostsPosition:
        if dist > manhattanDistance(pacmanPosition, ghost):
            dist = manhattanDistance(pacmanPosition, ghost)
            
    return dist

def manhattanFoodDistance(posA, posX, posY):
    return (abs(posX - posA[0]) + abs(posY - posA[1]))

def minDistBFS(agentPos, positions, wallGrid):
    # Toma paredes como celulas ja visitadas
    visited = wallGrid.copy()
    queue = []
    queue.append((agentPos,1))
    visited[agentPos[0]][agentPos[1]] = True
    if len(positions) > 0:
        while queue:
            el = queue.pop(0)
            h = el[1]
            s = el[0]

            north = (s[0],s[1]+1)
            south = (s[0],s[1]-1)
            west = (s[0]-1,s[1])
            east = (s[0]+1,s[1])

            for i in [north, south, west, east]:    
                if visited[i[0]][i[1]] == False:
                    queue.append((i,h+1))
                    visited[i[0]][i[1]] = True

                    if(i in positions):    
    #                     print (i, end = " ")
                        return h
                
    return 0

def findFoodMinDistBFS(agentPos, foodGrid, wallGrid):
    # Toma paredes como celulas ja visitadas
    visited = wallGrid.copy()
    queue = []
    queue.append((agentPos,1))
    visited[agentPos[0]][agentPos[1]] = True

    while queue:
        el = queue.pop(0)
        h = el[1]
        s = el[0]

        north = (s[0],s[1]+1)
        south = (s[0],s[1]-1)
        west = (s[0]-1,s[1])
        east = (s[0]+1,s[1])

        for i in [north, south, west, east]:    
            if visited[i[0]][i[1]] == False:
                queue.append((i,h+1))
                visited[i[0]][i[1]] = True

                if(foodGrid[i[0]][i[1]]):    
#                     print (i, end = " ")
                    return h
                
    return 0

def getMinDistEdibleGhost(agentPos,state):
    ghostPos = []
    ghostStates = state.getGhostStates()
    for gs in ghostStates:
        if gs.scaredTimer > 0:
            ghostPos.append(gs.getPosition())
            
    return minDistBFS(agentPos, ghostPos, state.getWalls())


def calcMinFoodDist(pacmanPosition, foodGrid):
    dist = 99999
    for i in range(1,len(foodGrid[:])-1):
        for j in range(1,len(foodGrid[0][:])-1):
            if foodGrid[i][j] and (dist > manhattanFoodDistance(pacmanPosition, i, j)):
                dist = manhattanFoodDistance(pacmanPosition, i, j)

    return dist

def calcMinPillDist(pacmanPosition, pills):
    return calcMinGhostDist(pacmanPosition, pills)

class MyGoWestAgent(Agent):
    "An agent that goes West until it can't."
    def __init__(self, tree = None):
        self.tree = tree
        
    def setTree(self, tree):
        selt.tree = tree

    def getAction(self, state):
        "The agent receives a GameState (defined in pacman.py)."
#         print(state.getLegalPacmanActions())
#         print(state.getPacmanState())

#         print(state.getPacmanPosition())
#         print(state.getNumFood())
#         print(state.getScore())
        count = 0
        legalActions = state.getLegalPacmanActions()
        legalActions.remove(Directions.STOP) #remove a opcao Stop
        actionScore = []
        stateVars = {}
        for action in legalActions:
            
            futureState = state.generatePacmanSuccessor(action)
            
            future_pos = futureState.getPacmanPosition()
            
            futureScore = futureState.getScore() - state.getScore()
            eatFood = state.getNumFood() - futureState.getNumFood()
            
            ghostDist = minDistBFS(future_pos, futureState.getGhostPositions(), state.getWalls())
            foodDist = findFoodMinDistBFS(future_pos,state.getFood(),state.getWalls())
            pillDist = minDistBFS(future_pos, state.getCapsules(), state.getWalls())
            edibleGhost = getMinDistEdibleGhost(future_pos,futureState)
            if ghostDist == 1:
                encounterGhost = 1
            else:
                encounterGhost = 0
            
            stateVars[STATE_VARS[0]] = futureScore
            stateVars[STATE_VARS[1]] = eatFood
            stateVars[STATE_VARS[2]] = ghostDist
            stateVars[STATE_VARS[3]] = foodDist
            stateVars[STATE_VARS[4]] = pillDist
            stateVars[STATE_VARS[5]] = edibleGhost
            stateVars[STATE_VARS[6]] = encounterGhost

            treeValue = tree.computeTree(stateVars)
            actionScore.append(treeValue)
            
        
        maxScore = max(actionScore)
        if actionScore.count(maxScore) > 1:
            indexes = [i for i, j in enumerate(actionScore) if j == maxScore]
            maxIndex = choice(indexes)
        else:
            maxIndex = actionScore.index(maxScore)
            
        
        
        action = legalActions[maxIndex]
        # print("Action Score: ",actionScore)
        
#         print("Action: ",action)
#         futureState = state.generatePacmanSuccessor(action)
#         futureScore = futureState.getScore() - state.getScore()
#         eatFood = state.getNumFood() - futureState.getNumFood()
#         ghostDist = calcMinGhostDist(futureState.getPacmanPosition(),futureState.getGhostPositions())
#         foodDist = calcMinFoodDist(futureState.getPacmanPosition(),futureState.getFood())
#         print("STATE VARS: FS: ", futureScore," EF: ", eatFood, " GD: ", ghostDist," FD: ", foodDist, " PD: ", pillDist)
        
        if action in state.getLegalPacmanActions():
            return action
        else:
            return Directions.STOP

# %%
import graphicsDisplay

gen_atual = 1
winsDict = {}

def trainIndividual(ind, gen, layoutType='smallClassic', numGames=5):
    gameLayout = layout.getLayout( 'smallClassic' )
    print("------------------------------------------ train --------------------")
    ind.print_tree()

    pacman = MyGoWestAgent(ind)

    ghostType = loadAgent('RandomGhost', True)
    ghosts = [ghostType( i+1 ) for i in range( 4 )]

    import textDisplay
    textDisplay.SLEEP_TIME = 0.1
    # gameDisplay = textDisplay.PacmanGraphics()
    gameDisplay = graphicsDisplay.PacmanGraphics(1.0, frameTime = 0.1)

    games = runGames( gameLayout, pacman, ghosts, gameDisplay, numGames, False)
    scores = [game.state.getScore() for game in games]
    wins = [game.state.isWin() for game in games]
    winRate = wins.count(True)/ float(len(wins))
    
    winsDict[str(gen)].append(winRate)
    
    avgScore = sum(scores) / float(len(scores))
    return avgScore

# %%
def compareTrees(tree1, tree2):
    if (not tree1 and tree2 != None) or (not tree2 and tree1 != None):
        return False
    if tree1.data != tree2.data:
        return False
    if not tree1.data and not tree2.data:
        return True
    return compareTrees(tree1.left, tree2.left) and compareTrees(tree1.right, tree2.right)

def generationLoop():
    population = initialPopulation(POP_SIZE, TREE_SIZE) # popSize, tam GPTree
#     fitness = np.zeros((1,len(population)))
    
    genFits = []
    maxFits = []
    minFits = []
    
    count = 1
    
    winsDict[str(count)] = []
    
    for p in population:
        p.print_tree()
        print(" - - - - ")
    print("G - ",count,"    ============================================  ")
    
    # train population to get fitness
        
    fitness = getPopFitness(population, count)
    print("G",count," - FITNESS: ", fitness )
    while count <= NUM_GEN: # gen
        
        
        children = []
        
        for i in range(0,int(len(population)/4)-1):
            father = getParent(population, fitness,3)
            mother = getParent(population, fitness,3)
            
            # TODO - check if parent == mother
            
            child1, child2 = crossover(father, mother)
            children.append(child1)
            children.append(child2)
            

#       children = mutation(children,int(len(children)*0.75))#mutation
        indexes = np.random.choice(range(0,len(children)),int(len(children)*0.75),False)
        for i in indexes:
            children[i].mutation(0.2)
        
        # elitism
        maxIndex = fitness.index(max(fitness))
        children.append(population[maxIndex])
        
        fitness.remove(max(fitness))
        population.remove(population[maxIndex])
        
        maxIndex = fitness.index(max(fitness))
        children.append(population[maxIndex])
        
        count += 1
        
        winsDict[str(count)] = []
        
        # train population to get fitness
        print("G", count," - POPULATION")
        
        population = children[:]
        for p in population:
            p.print_tree()
            print(" - - - - ")
            
        fitness = getPopFitness(population, count)
        # colocar fitness em um vetor
        #      - Pop
        #      - Max
        #      - Min
        print("FITNESS: ", fitness )
        avgFit = sum(fitness) / float(len(fitness))
        print("Avg: ", avgFit)
        genFits.append(avgFit)
        maxFit = max(fitness)
        print("Max: ", maxFit)
        maxFits.append(maxFit)
        minFit = min(fitness)
        print("Min: ", minFit)
        minFits.append(minFit)
    
    print("gen means: ", genFits)
    print("gen maxes: ", maxFits)
    print("gen mins: ", minFits)
    
    x = np.linspace(1, NUM_GEN, num= NUM_GEN, endpoint=True)
    y1 = np.array(genFits)
    y2 = np.array(maxFits)
    y3 = np.array(minFits)
    
    plt.plot(x, y1, '-', x, y2, '-', x, y3, '-')
    plt.legend(['mean', 'max', 'min'], loc='best')
    plt.show()
    
    return population, fitness

# %%
NUM_GEN = 40
POP_SIZE = 48
TREE_SIZE = 4

population, fitness = generationLoop()
for p in population:
    p.print_tree()
    print(" - - - - ")
print(fitness)

print(winsDict)
# Out:
# mul
#    add
#       sub
#          add
#             distToPill
#             distToPill
#          mul
#             distToPill
#             eatFood
#       distToPill
#    sub
#       minDistEdibleGhost
#       actionScore
#  - - - -
# mul
#    add
#       2.0
#       mul
#          0.5
#          mul
#             minDistToFood
#             0.5
#    sub
#       minDistEdibleGhost
#       sub
#          sub
#             distToPill
#             distToPill
#          minDistEdibleGhost
#  - - - -
# mul
#    sub
#       mul
#          distToPill
#          0.5
#       mul
#          actionScore
#          minDistEdibleGhost
#    mul
#       mul
#          sub
#             1.0
#             actionScore
#          minGhostDist
#       1.0
#  - - - -
# mul
#    mul
#       minDistToFood
#       eatFood
#    sub
#       sub
#          sub
#             distToPill
#             2.0
#          add
#             actionScore
#             2.0
#       mul
#          sub
#             -1.0
#             minDistToFood
#          2.0
#  - - - -
# mul
#    add
#       sub
#          sub
#             eatFood
#             distToPill
#          1.0
#       add
#          sub
#             eatFood
#             eatFood
#          mul
#             2.0
#             -1.0
#    sub
#       minGhostDist
#       mul
#          mul
#             distToPill
#             eatFood
#          add
#             minDistToFood
#             minDistEdibleGhost
#  - - - -
# sub
#    sub
#       sub
#          mul
#             minGhostDist
#             -1.0
#          mul
#             minDistEdibleGhost
#             minDistEdibleGhost
#       -1.0
#    add
#       -1.0
#       eatFood
#  - - - -
# add
#    add
#       add
#          minGhostDist
#          distToPill
#       1.0
#    mul
#       1.0
#       actionScore
#  - - - -
# sub
#    sub
#       minDistEdibleGhost
#       actionScore
#    mul
#       sub
#          add
#             -1.0
#             minDistToFood
#          mul
#             eatFood
#             minGhostDist
#       mul
#          mul
#             distToPill
#             minDistToFood
#          minDistEdibleGhost
#  - - - -
# sub
#    sub
#       sub
#          sub
#             minDistToFood
#             1.0
#          mul
#             1.0
#             minGhostDist
#       sub
#          add
#             actionScore
#             eatFood
#          actionScore
#    add
#       mul
#          add
#             minDistToFood
#             -1.0
#          add
#             minGhostDist
#             -1.0
#       sub
#          minDistToFood
#          minDistToFood
#  - - - -
# add
#    mul
#       distToPill
#       minDistToFood
#    sub
#       sub
#          sub
#             eatFood
#             eatFood
#          add
#             2.0
#             distToPill
#       2.0
#  - - - -
# add
#    add
#       eatFood
#       sub
#          minDistToFood
#          eatFood
#    add
#       sub
#          mul
#             minDistToFood
#             1.0
#          2.0
#       mul
#          add
#             minDistToFood
#             actionScore
#          0.5
#  - - - -
# mul
#    add
#       mul
#          1.0
#          eatFood
#       mul
#          minDistEdibleGhost
#          mul
#             minDistEdibleGhost
#             2.0
#    mul
#       2.0
#       actionScore
#  - - - -
# mul
#    mul
#       distToPill
#       2.0
#    sub
#       minDistEdibleGhost
#       0.5
#  - - - -
# add
#    mul
#       -1.0
#       eatFood
#    add
#       mul
#          0.5
#          mul
#             eatFood
#             1.0
#       mul
#          2.0
#          1.0
#  - - - -
# sub
#    sub
#       minGhostDist
#       minDistToFood
#    mul
#       minGhostDist
#       2.0
#  - - - -
# add
#    mul
#       minDistEdibleGhost
#       minDistToFood
#    add
#       add
#          sub
#             distToPill
#             minDistEdibleGhost
#          eatFood
#       minGhostDist
#  - - - -
# add
#    mul
#       0.5
#       mul
#          2.0
#          minDistToFood
#    sub
#       mul
#          minDistToFood
#          sub
#             minDistToFood
#             2.0
#       0.5
#  - - - -
# mul
#    mul
#       minGhostDist
#       sub
#          mul
#             1.0
#             actionScore
#          sub
#             minGhostDist
#             1.0
#    add
#       actionScore
#       sub
#          actionScore
#          minGhostDist
#  - - - -
# mul
#    mul
#       sub
#          sub
#             distToPill
#             1.0
#          minGhostDist
#       sub
#          sub
#             eatFood
#             minDistEdibleGhost
#          sub
#             0.5
#             eatFood
#    sub
#       1.0
#       add
#          -1.0
#          eatFood
#  - - - -
# sub
#    sub
#       distToPill
#       actionScore
#    add
#       eatFood
#       minDistEdibleGhost
#  - - - -
# sub
#    sub
#       1.0
#       minDistEdibleGhost
#    sub
#       2.0
#       minDistEdibleGhost
#  - - - -
# add
#    add
#       mul
#          2.0
#          add
#             minDistEdibleGhost
#             distToPill
#       actionScore
#    sub
#       minGhostDist
#       -1.0
#  - - - -
# add
#    mul
#       add
#          sub
#             minDistEdibleGhost
#             -1.0
#          actionScore
#       2.0
#    add
#       distToPill
#       mul
#          mul
#             actionScore
#             minDistEdibleGhost
#          eatFood
#  - - - -
# add
#    add
#       minDistEdibleGhost
#       add
#          sub
#             minGhostDist
#             eatFood
#          eatFood
#    mul
#       minDistEdibleGhost
#       add
#          mul
#             minDistEdibleGhost
#             0.5
#          mul
#             minGhostDist
#             minGhostDist
#  - - - -
# sub
#    add
#       minDistEdibleGhost
#       0.5
#    sub
#       add
#          0.5
#          mul
#             2.0
#             minGhostDist
#       minDistToFood
#  - - - -
# sub
#    add
#       -1.0
#       add
#          mul
#             -1.0
#             0.5
#          minDistEdibleGhost
#    add
#       add
#          2.0
#          mul
#             -1.0
#             minDistToFood
#       2.0
#  - - - -
# sub
#    add
#       add
#          sub
#             actionScore
#             -1.0
#          add
#             actionScore
#             0.5
#       sub
#          add
#             distToPill
#             -1.0
#          sub
#             1.0
#             2.0
#    mul
#       mul
#          mul
#             minDistEdibleGhost
#             distToPill
#          sub
#             distToPill
#             1.0
#       mul
#          actionScore
#          -1.0
#  - - - -
# add
#    add
#       0.5
#       sub
#          0.5
#          add
#             0.5
#             -1.0
#    mul
#       distToPill
#       distToPill
#  - - - -
# add
#    mul
#       sub
#          add
#             distToPill
#             eatFood
#          0.5
#       0.5
#    add
#       add
#          minDistToFood
#          distToPill
#       eatFood
#  - - - -
# sub
#    sub
#       1.0
#       add
#          add
#             distToPill
#             minGhostDist
#          minDistEdibleGhost
#    sub
#       minDistToFood
#       add
#          minDistToFood
#          mul
#             0.5
#             1.0
#  - - - -
# sub
#    sub
#       minDistToFood
#       mul
#          actionScore
#          add
#             eatFood
#             0.5
#    sub
#       minDistEdibleGhost
#       sub
#          sub
#             eatFood
#             minDistEdibleGhost
#          eatFood
#  - - - -
# mul
#    sub
#       add
#          add
#             distToPill
#             1.0
#          actionScore
#       eatFood
#    sub
#       minDistEdibleGhost
#       add
#          eatFood
#          add
#             1.0
#             actionScore
#  - - - -
# sub
#    sub
#       0.5
#       mul
#          0.5
#          2.0
#    mul
#       minDistEdibleGhost
#       add
#          0.5
#          minDistEdibleGhost
#  - - - -
# sub
#    sub
#       0.5
#       eatFood
#    mul
#       add
#          add
#             distToPill
#             0.5
#          0.5
#       mul
#          1.0
#          mul
#             1.0
#             minGhostDist
#  - - - -
# sub
#    add
#       mul
#          minDistEdibleGhost
#          add
#             minDistEdibleGhost
#             1.0
#       mul
#          add
#             1.0
#             minDistEdibleGhost
#          -1.0
#    mul
#       add
#          minDistEdibleGhost
#          add
#             -1.0
#             minGhostDist
#       add
#          add
#             2.0
#             eatFood
#          distToPill
#  - - - -
# sub
#    mul
#       mul
#          mul
#             minDistEdibleGhost
#             actionScore
#          mul
#             distToPill
#             distToPill
#       add
#          -1.0
#          sub
#             minDistEdibleGhost
#             eatFood
#    mul
#       0.5
#       mul
#          distToPill
#          2.0
#  - - - -
# mul
#    add
#       2.0
#       mul
#          mul
#             actionScore
#             eatFood
#          1.0
#    sub
#       add
#          add
#             2.0
#             actionScore
#          minGhostDist
#       mul
#          sub
#             2.0
#             eatFood
#          minDistToFood
#  - - - -
# mul
#    add
#       add
#          2.0
#          distToPill
#       minDistToFood
#    add
#       actionScore
#       mul
#          add
#             0.5
#             1.0
#          add
#             minDistToFood
#             minGhostDist
#  - - - -
# mul
#    mul
#       add
#          add
#             minGhostDist
#             distToPill
#          sub
#             1.0
#             minGhostDist
#       distToPill
#    mul
#       mul
#          2.0
#          sub
#             minDistEdibleGhost
#             minDistToFood
#       sub
#          add
#             0.5
#             actionScore
#          sub
#             2.0
#             minDistEdibleGhost
#  - - - -
# add
#    sub
#       2.0
#       sub
#          sub
#             distToPill
#             actionScore
#          -1.0
#    sub
#       minGhostDist
#       mul
#          sub
#             2.0
#             minDistEdibleGhost
#          sub
#             minGhostDist
#             1.0
#  - - - -
# add
#    sub
#       add
#          sub
#             actionScore
#             minGhostDist
#          minDistToFood
#       mul
#          sub
#             actionScore
#             2.0
#          add
#             distToPill
#             2.0
#    add
#       1.0
#       -1.0
#  - - - -
# add
#    add
#       mul
#          sub
#             distToPill
#             -1.0
#          0.5
#       sub
#          minGhostDist
#          mul
#             2.0
#             distToPill
#    sub
#       actionScore
#       add
#          add
#             distToPill
#             2.0
#          0.5
#  - - - -
# sub
#    mul
#       minGhostDist
#       mul
#          distToPill
#          1.0
#    add
#       2.0
#       0.5
#  - - - -
# add
#    mul
#       add
#          minDistEdibleGhost
#          add
#             2.0
#             eatFood
#       sub
#          minDistEdibleGhost
#          mul
#             -1.0
#             minDistEdibleGhost
#    add
#       distToPill
#       sub
#          add
#             actionScore
#             minDistToFood
#          minGhostDist
#  - - - -
# mul
#    sub
#       minGhostDist
#       minDistEdibleGhost
#    sub
#       eatFood
#       sub
#          add
#             minDistToFood
#             distToPill
#          2.0
#  - - - -
# sub
#    mul
#       1.0
#       sub
#          2.0
#          0.5
#    add
#       mul
#          -1.0
#          0.5
#       2.0
#  - - - -
# add
#    mul
#       mul
#          sub
#             actionScore
#             -1.0
#          eatFood
#       add
#          sub
#             minDistEdibleGhost
#             0.5
#          mul
#             minDistToFood
#             2.0
#    mul
#       0.5
#       sub
#          sub
#             minGhostDist
#             -1.0
#          mul
#             0.5
#             1.0
#  - - - -
# add
#    mul
#       add
#          sub
#             actionScore
#             0.5
#          minGhostDist
#       sub
#          distToPill
#          mul
#             1.0
#             eatFood
#    sub
#       -1.0
#       sub
#          1.0
#          sub
#             distToPill
#             actionScore
#  - - - -
# G -  1     ============================================
# layout:  smallClassic
# ------------------------------------------ train --------------------
# mul
#    add
#       sub
#          add
#             distToPill
#             distToPill
#          mul
#             distToPill
#             eatFood
#       distToPill
#    sub
#       minDistEdibleGhost
#       actionScore
# Pacman died! Score: -428
# Pacman died! Score: -435
# Pacman died! Score: -428
# Pacman died! Score: -446
# Pacman died! Score: -233
# Pacman died! Score: -258
# Pacman died! Score: -428
# Pacman died! Score: -389
# Pacman died! Score: -446
# Pacman died! Score: -429
# Average Score: -392.0
# Scores:        -428.0, -435.0, -428.0, -446.0, -233.0, -258.0, -428.0, -389.0, -446.0, -429.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# mul
#    add
#       2.0
#       mul
#          0.5
#          mul
#             minDistToFood
#             0.5
#    sub
#       minDistEdibleGhost
#       sub
#          sub
#             distToPill
#             distToPill
#          minDistEdibleGhost
# Pacman died! Score: -430
# Pacman died! Score: -446
# Pacman died! Score: -428
# Pacman died! Score: -139
# Pacman died! Score: -392
# Pacman died! Score: -428
# Pacman died! Score: -379
# Pacman died! Score: -260
# Pacman died! Score: -354
# Pacman died! Score: -428
# Average Score: -368.4
# Scores:        -430.0, -446.0, -428.0, -139.0, -392.0, -428.0, -379.0, -260.0, -354.0, -428.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# mul
#    sub
#       mul
#          distToPill
#          0.5
#       mul
#          actionScore
#          minDistEdibleGhost
#    mul
#       mul
#          sub
#             1.0
#             actionScore
#          minGhostDist
#       1.0
# Pacman died! Score: -430
# Pacman died! Score: -452
# Pacman died! Score: -446
# Pacman died! Score: -342
# Pacman died! Score: -446
# Pacman died! Score: -430
# Pacman died! Score: -447
# Pacman died! Score: -428
# Pacman died! Score: -429
# Pacman died! Score: -432
# Average Score: -428.2
# Scores:        -430.0, -452.0, -446.0, -342.0, -446.0, -430.0, -447.0, -428.0, -429.0, -432.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# mul
#    mul
#       minDistToFood
#       eatFood
#    sub
#       sub
#          sub
#             distToPill
#             2.0
#          add
#             actionScore
#             2.0
#       mul
#          sub
#             -1.0
#             minDistToFood
#          2.0
# Pacman died! Score: -446
# Pacman died! Score: -428
# Pacman died! Score: -202
# Pacman died! Score: 73
# Pacman died! Score: -429
# Pacman died! Score: -446
# Pacman died! Score: -241
# Pacman died! Score: -446
# Pacman died! Score: -95
# Pacman died! Score: -260
# Average Score: -292.0
# Scores:        -446.0, -428.0, -202.0, 73.0, -429.0, -446.0, -241.0, -446.0, -95.0, -260.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# mul
#    add
#       sub
#          sub
#             eatFood
#             distToPill
#          1.0
#       add
#          sub
#             eatFood
#             eatFood
#          mul
#             2.0
#             -1.0
#    sub
#       minGhostDist
#       mul
#          mul
#             distToPill
#             eatFood
#          add
#             minDistToFood
#             minDistEdibleGhost
# Pacman died! Score: -359
# Pacman died! Score: -437
# Pacman died! Score: -311
# Pacman died! Score: -428
# Pacman died! Score: -351
# Pacman died! Score: -239
# Pacman died! Score: -446
# Pacman died! Score: -428
# Pacman died! Score: -430
# Pacman died! Score: -430
# Average Score: -385.9
# Scores:        -359.0, -437.0, -311.0, -428.0, -351.0, -239.0, -446.0, -428.0, -430.0, -430.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# sub
#    sub
#       sub
#          mul
#             minGhostDist
#             -1.0
#          mul
#             minDistEdibleGhost
#             minDistEdibleGhost
#       -1.0
#    add
#       -1.0
#       eatFood
# Pacman died! Score: -431
# Pacman died! Score: -446
# Pacman died! Score: -429
# Pacman died! Score: -370
# Pacman died! Score: -452
# Pacman died! Score: -446
# Pacman died! Score: -49
# Pacman died! Score: -429
# Pacman died! Score: -431
# Pacman died! Score: -80
# Average Score: -356.3
# Scores:        -431.0, -446.0, -429.0, -370.0, -452.0, -446.0, -49.0, -429.0, -431.0, -80.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    add
#       add
#          minGhostDist
#          distToPill
#       1.0
#    mul
#       1.0
#       actionScore
# Pacman died! Score: -383
# Pacman died! Score: -431
# Pacman died! Score: -294
# Pacman died! Score: -437
# Pacman died! Score: -446
# Pacman died! Score: -446
# Pacman died! Score: -437
# Pacman died! Score: -446
# Pacman died! Score: -429
# Pacman died! Score: -446
# Average Score: -419.5
# Scores:        -383.0, -431.0, -294.0, -437.0, -446.0, -446.0, -437.0, -446.0, -429.0, -446.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# sub
#    sub
#       minDistEdibleGhost
#       actionScore
#    mul
#       sub
#          add
#             -1.0
#             minDistToFood
#          mul
#             eatFood
#             minGhostDist
#       mul
#          mul
#             distToPill
#             minDistToFood
#          minDistEdibleGhost
# Pacman died! Score: -431
# Pacman died! Score: -347
# Pacman died! Score: -446
# Pacman died! Score: -446
# Pacman died! Score: -436
# Pacman died! Score: -431
# Pacman died! Score: -430
# Pacman died! Score: -446
# Pacman died! Score: -434
# Pacman died! Score: -361
# Average Score: -420.8
# Scores:        -431.0, -347.0, -446.0, -446.0, -436.0, -431.0, -430.0, -446.0, -434.0, -361.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# sub
#    sub
#       sub
#          sub
#             minDistToFood
#             1.0
#          mul
#             1.0
#             minGhostDist
#       sub
#          add
#             actionScore
#             eatFood
#          actionScore
#    add
#       mul
#          add
#             minDistToFood
#             -1.0
#          add
#             minGhostDist
#             -1.0
#       sub
#          minDistToFood
#          minDistToFood
# Pacman died! Score: -430
# Pacman died! Score: -429
# Pacman died! Score: -446
# Pacman died! Score: -431
# Pacman died! Score: -429
# Pacman died! Score: -437
# Pacman died! Score: -430
# Pacman died! Score: -437
# Pacman died! Score: -305
# Pacman died! Score: -127
# Average Score: -390.1
# Scores:        -430.0, -429.0, -446.0, -431.0, -429.0, -437.0, -430.0, -437.0, -305.0, -127.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    mul
#       distToPill
#       minDistToFood
#    sub
#       sub
#          sub
#             eatFood
#             eatFood
#          add
#             2.0
#             distToPill
#       2.0
# Pacman died! Score: -329
# Pacman died! Score: -446
# Pacman died! Score: -335
# Pacman died! Score: -392
# Pacman died! Score: -446
# Pacman died! Score: -428
# Pacman died! Score: -359
# Pacman died! Score: -446
# Pacman died! Score: -446
# Pacman died! Score: -428
# Average Score: -405.5
# Scores:        -329.0, -446.0, -335.0, -392.0, -446.0, -428.0, -359.0, -446.0, -446.0, -428.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    add
#       eatFood
#       sub
#          minDistToFood
#          eatFood
#    add
#       sub
#          mul
#             minDistToFood
#             1.0
#          2.0
#       mul
#          add
#             minDistToFood
#             actionScore
#          0.5
# Pacman died! Score: -446
# Pacman died! Score: -446
# Pacman died! Score: -342
# Pacman died! Score: -430
# Pacman died! Score: -446
# Pacman died! Score: -446
# Pacman died! Score: -430
# Pacman died! Score: -437
# Pacman died! Score: -365
# Pacman died! Score: -375
# Average Score: -416.3
# Scores:        -446.0, -446.0, -342.0, -430.0, -446.0, -446.0, -430.0, -437.0, -365.0, -375.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# mul
#    add
#       mul
#          1.0
#          eatFood
#       mul
#          minDistEdibleGhost
#          mul
#             minDistEdibleGhost
#             2.0
#    mul
#       2.0
#       actionScore
# Pacman died! Score: -431
# Pacman died! Score: 116
# Pacman died! Score: 98
# Pacman died! Score: -292
# Pacman died! Score: -133
# Pacman died! Score: -351
# Pacman died! Score: -351
# Pacman died! Score: -367
# Pacman died! Score: -347
# Pacman died! Score: -446
# Average Score: -250.4
# Scores:        -431.0, 116.0, 98.0, -292.0, -133.0, -351.0, -351.0, -367.0, -347.0, -446.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# mul
#    mul
#       distToPill
#       2.0
#    sub
#       minDistEdibleGhost
#       0.5
# Pacman died! Score: -446
# Pacman died! Score: -437
# Pacman died! Score: -446
# Pacman died! Score: -429
# Pacman died! Score: -348
# Pacman died! Score: -446
# Pacman died! Score: -446
# Pacman died! Score: -446
# Pacman died! Score: -348
# Pacman died! Score: -446
# Average Score: -423.8
# Scores:        -446.0, -437.0, -446.0, -429.0, -348.0, -446.0, -446.0, -446.0, -348.0, -446.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    mul
#       -1.0
#       eatFood
#    add
#       mul
#          0.5
#          mul
#             eatFood
#             1.0
#       mul
#          2.0
#          1.0
# Pacman died! Score: -131
# Pacman died! Score: -269
# Pacman died! Score: 118
# Pacman died! Score: -428
# Pacman died! Score: -446
# Pacman died! Score: -429
# Pacman died! Score: -431
# Pacman died! Score: -446
# Pacman died! Score: -451
# Pacman died! Score: -437
# Average Score: -335.0
# Scores:        -131.0, -269.0, 118.0, -428.0, -446.0, -429.0, -431.0, -446.0, -451.0, -437.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# sub
#    sub
#       minGhostDist
#       minDistToFood
#    mul
#       minGhostDist
#       2.0
# Pacman died! Score: -446
# Pacman died! Score: -104
# Pacman died! Score: -404
# Pacman died! Score: -437
# Pacman died! Score: 62
# Pacman died! Score: -284
# Pacman died! Score: -430
# Pacman died! Score: -459
# Pacman died! Score: -446
# Pacman died! Score: -429
# Average Score: -337.7
# Scores:        -446.0, -104.0, -404.0, -437.0, 62.0, -284.0, -430.0, -459.0, -446.0, -429.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    mul
#       minDistEdibleGhost
#       minDistToFood
#    add
#       add
#          sub
#             distToPill
#             minDistEdibleGhost
#          eatFood
#       minGhostDist
# Pacman died! Score: -374
# Pacman died! Score: -419
# Pacman died! Score: -437
# Pacman died! Score: -430
# Pacman died! Score: -446
# Pacman died! Score: -446
# Pacman died! Score: -435
# Pacman died! Score: -446
# Pacman died! Score: -266
# Pacman died! Score: -270
# Average Score: -396.9
# Scores:        -374.0, -419.0, -437.0, -430.0, -446.0, -446.0, -435.0, -446.0, -266.0, -270.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    mul
#       0.5
#       mul
#          2.0
#          minDistToFood
#    sub
#       mul
#          minDistToFood
#          sub
#             minDistToFood
#             2.0
#       0.5
# Pacman died! Score: -400
# Pacman died! Score: -446
# Pacman died! Score: -414
# Pacman died! Score: -446
# Pacman died! Score: -428
# Pacman died! Score: -428
# Pacman died! Score: -428
# Pacman died! Score: -316
# Pacman died! Score: -446
# Pacman died! Score: -449
# Average Score: -420.1
# Scores:        -400.0, -446.0, -414.0, -446.0, -428.0, -428.0, -428.0, -316.0, -446.0, -449.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# mul
#    mul
#       minGhostDist
#       sub
#          mul
#             1.0
#             actionScore
#          sub
#             minGhostDist
#             1.0
#    add
#       actionScore
#       sub
#          actionScore
#          minGhostDist
# Pacman died! Score: -267
# Pacman died! Score: -75
# Pacman died! Score: -437
# Pacman died! Score: -213
# Pacman died! Score: -428
# Pacman died! Score: -195
# Pacman died! Score: -407
# Pacman died! Score: -446
# Pacman died! Score: -247
# Pacman died! Score: -318
# Average Score: -303.3
# Scores:        -267.0, -75.0, -437.0, -213.0, -428.0, -195.0, -407.0, -446.0, -247.0, -318.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# mul
#    mul
#       sub
#          sub
#             distToPill
#             1.0
#          minGhostDist
#       sub
#          sub
#             eatFood
#             minDistEdibleGhost
#          sub
#             0.5
#             eatFood
#    sub
#       1.0
#       add
#          -1.0
#          eatFood
# Pacman died! Score: -429
# Pacman died! Score: -352
# Pacman died! Score: -241
# Pacman died! Score: -365
# Pacman died! Score: -104
# Pacman died! Score: -249
# Pacman died! Score: -320
# Pacman died! Score: -430
# Pacman died! Score: -430
# Pacman died! Score: -429
# Average Score: -334.9
# Scores:        -429.0, -352.0, -241.0, -365.0, -104.0, -249.0, -320.0, -430.0, -430.0, -429.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# sub
#    sub
#       distToPill
#       actionScore
#    add
#       eatFood
#       minDistEdibleGhost
# Pacman died! Score: -238
# Pacman died! Score: -315
# Pacman died! Score: -430
# Pacman died! Score: -299
# Pacman died! Score: -296
# Pacman died! Score: -446
# Pacman died! Score: -435
# Pacman died! Score: -234
# Pacman died! Score: -281
# Pacman died! Score: -387
# Average Score: -336.1
# Scores:        -238.0, -315.0, -430.0, -299.0, -296.0, -446.0, -435.0, -234.0, -281.0, -387.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# sub
#    sub
#       1.0
#       minDistEdibleGhost
#    sub
#       2.0
#       minDistEdibleGhost
# Pacman died! Score: -340
# Pacman died! Score: -338
# Pacman died! Score: -429
# Pacman died! Score: -432
# Pacman died! Score: -365
# Pacman died! Score: -446
# Pacman died! Score: -446
# Pacman died! Score: -431
# Pacman died! Score: -238
# Pacman died! Score: -428
# Average Score: -389.3
# Scores:        -340.0, -338.0, -429.0, -432.0, -365.0, -446.0, -446.0, -431.0, -238.0, -428.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    add
#       mul
#          2.0
#          add
#             minDistEdibleGhost
#             distToPill
#       actionScore
#    sub
#       minGhostDist
#       -1.0
# Pacman died! Score: -428
# Pacman died! Score: -445
# Pacman died! Score: -430
# Pacman died! Score: -340
# Pacman died! Score: -428
# Pacman died! Score: -446
# Pacman died! Score: -428
# Pacman died! Score: -401
# Pacman died! Score: -336
# Pacman died! Score: -432
# Average Score: -411.4
# Scores:        -428.0, -445.0, -430.0, -340.0, -428.0, -446.0, -428.0, -401.0, -336.0, -432.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    mul
#       add
#          sub
#             minDistEdibleGhost
#             -1.0
#          actionScore
#       2.0
#    add
#       distToPill
#       mul
#          mul
#             actionScore
#             minDistEdibleGhost
#          eatFood
# Pacman died! Score: -430
# Pacman died! Score: -428
# Pacman died! Score: -446
# Pacman died! Score: -441
# Pacman died! Score: -428
# Pacman died! Score: -365
# Pacman died! Score: -446
# Pacman died! Score: -429
# Pacman died! Score: -430
# Pacman died! Score: -265
# Average Score: -410.8
# Scores:        -430.0, -428.0, -446.0, -441.0, -428.0, -365.0, -446.0, -429.0, -430.0, -265.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    add
#       minDistEdibleGhost
#       add
#          sub
#             minGhostDist
#             eatFood
#          eatFood
#    mul
#       minDistEdibleGhost
#       add
#          mul
#             minDistEdibleGhost
#             0.5
#          mul
#             minGhostDist
#             minGhostDist
# Pacman died! Score: -343
# Pacman died! Score: -428
# Pacman died! Score: -429
# Pacman died! Score: -428
# Pacman died! Score: -428
# Pacman died! Score: -276
# Pacman died! Score: -377
# Pacman died! Score: -428
# Pacman died! Score: -264
# Pacman died! Score: -437
# Average Score: -383.8
# Scores:        -343.0, -428.0, -429.0, -428.0, -428.0, -276.0, -377.0, -428.0, -264.0, -437.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# sub
#    add
#       minDistEdibleGhost
#       0.5
#    sub
#       add
#          0.5
#          mul
#             2.0
#             minGhostDist
#       minDistToFood
# Pacman died! Score: -315
# Pacman died! Score: -446
# Pacman died! Score: -437
# Pacman died! Score: -446
# Pacman died! Score: -383
# Pacman died! Score: -428
# Pacman died! Score: -429
# Pacman died! Score: -340
# Pacman died! Score: -430
# Pacman died! Score: -429
# Average Score: -408.3
# Scores:        -315.0, -446.0, -437.0, -446.0, -383.0, -428.0, -429.0, -340.0, -430.0, -429.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# sub
#    add
#       -1.0
#       add
#          mul
#             -1.0
#             0.5
#          minDistEdibleGhost
#    add
#       add
#          2.0
#          mul
#             -1.0
#             minDistToFood
#       2.0
# Pacman died! Score: -380
# Pacman died! Score: -234
# Pacman died! Score: -428
# Pacman died! Score: -430
# Pacman died! Score: -429
# Pacman died! Score: -446
# Pacman died! Score: -236
# Pacman died! Score: -452
# Pacman died! Score: -427
# Pacman died! Score: -428
# Average Score: -389.0
# Scores:        -380.0, -234.0, -428.0, -430.0, -429.0, -446.0, -236.0, -452.0, -427.0, -428.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# sub
#    add
#       add
#          sub
#             actionScore
#             -1.0
#          add
#             actionScore
#             0.5
#       sub
#          add
#             distToPill
#             -1.0
#          sub
#             1.0
#             2.0
#    mul
#       mul
#          mul
#             minDistEdibleGhost
#             distToPill
#          sub
#             distToPill
#             1.0
#       mul
#          actionScore
#          -1.0
# Pacman died! Score: -257
# Pacman died! Score: -428
# Pacman died! Score: -429
# Pacman died! Score: -446
# Pacman died! Score: -428
# Pacman died! Score: 94
# Pacman died! Score: -408
# Pacman died! Score: -446
# Pacman died! Score: -326
# Pacman died! Score: -376
# Average Score: -345.0
# Scores:        -257.0, -428.0, -429.0, -446.0, -428.0, 94.0, -408.0, -446.0, -326.0, -376.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    add
#       0.5
#       sub
#          0.5
#          add
#             0.5
#             -1.0
#    mul
#       distToPill
#       distToPill
# Pacman died! Score: -351
# Pacman died! Score: -446
# Pacman died! Score: -446
# Pacman died! Score: -446
# Pacman died! Score: -429
# Pacman died! Score: -352
# Pacman died! Score: -430
# Pacman died! Score: -432
# Pacman died! Score: -430
# Pacman died! Score: -429
# Average Score: -419.1
# Scores:        -351.0, -446.0, -446.0, -446.0, -429.0, -352.0, -430.0, -432.0, -430.0, -429.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    mul
#       sub
#          add
#             distToPill
#             eatFood
#          0.5
#       0.5
#    add
#       add
#          minDistToFood
#          distToPill
#       eatFood
# Pacman died! Score: -389
# Pacman died! Score: -446
# Pacman died! Score: 31
# Pacman died! Score: -368
# Pacman died! Score: -374
# Pacman died! Score: -430
# Pacman died! Score: -446
# Pacman died! Score: -429
# Pacman died! Score: -428
# Pacman died! Score: -437
# Average Score: -371.6
# Scores:        -389.0, -446.0, 31.0, -368.0, -374.0, -430.0, -446.0, -429.0, -428.0, -437.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# sub
#    sub
#       1.0
#       add
#          add
#             distToPill
#             minGhostDist
#          minDistEdibleGhost
#    sub
#       minDistToFood
#       add
#          minDistToFood
#          mul
#             0.5
#             1.0
# Pacman died! Score: -430
# Pacman died! Score: -437
# Pacman died! Score: -287
# Pacman died! Score: 61
# Pacman died! Score: -430
# Pacman died! Score: -446
# Pacman died! Score: -428
# Pacman died! Score: -428
# Pacman died! Score: -446
# Pacman died! Score: -428
# Average Score: -369.9
# Scores:        -430.0, -437.0, -287.0, 61.0, -430.0, -446.0, -428.0, -428.0, -446.0, -428.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# sub
#    sub
#       minDistToFood
#       mul
#          actionScore
#          add
#             eatFood
#             0.5
#    sub
#       minDistEdibleGhost
#       sub
#          sub
#             eatFood
#             minDistEdibleGhost
#          eatFood
# Pacman died! Score: -446
# Pacman died! Score: -241
# Pacman died! Score: -118
# Pacman died! Score: -324
# Pacman died! Score: -428
# Pacman died! Score: -248
# Pacman died! Score: 112
# Pacman died! Score: -127
# Pacman died! Score: -446
# Pacman died! Score: -430
# Average Score: -269.6
# Scores:        -446.0, -241.0, -118.0, -324.0, -428.0, -248.0, 112.0, -127.0, -446.0, -430.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# mul
#    sub
#       add
#          add
#             distToPill
#             1.0
#          actionScore
#       eatFood
#    sub
#       minDistEdibleGhost
#       add
#          eatFood
#          add
#             1.0
#             actionScore
# Pacman died! Score: -428
# Pacman died! Score: -381
# Pacman died! Score: -450
# Pacman died! Score: -429
# Pacman died! Score: -178
# Pacman died! Score: -443
# Pacman died! Score: -244
# Pacman died! Score: -446
# Pacman died! Score: -320
# Pacman died! Score: -356
# Average Score: -367.5
# Scores:        -428.0, -381.0, -450.0, -429.0, -178.0, -443.0, -244.0, -446.0, -320.0, -356.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# sub
#    sub
#       0.5
#       mul
#          0.5
#          2.0
#    mul
#       minDistEdibleGhost
#       add
#          0.5
#          minDistEdibleGhost
# Pacman died! Score: -398
# Pacman died! Score: -429
# Pacman died! Score: -446
# Pacman died! Score: -125
# Pacman died! Score: -226
# Pacman died! Score: -429
# Pacman died! Score: -429
# Pacman died! Score: -446
# Pacman died! Score: -429
# Pacman died! Score: -451
# Average Score: -380.8
# Scores:        -398.0, -429.0, -446.0, -125.0, -226.0, -429.0, -429.0, -446.0, -429.0, -451.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# sub
#    sub
#       0.5
#       eatFood
#    mul
#       add
#          add
#             distToPill
#             0.5
#          0.5
#       mul
#          1.0
#          mul
#             1.0
#             minGhostDist
# Pacman died! Score: -339
# Pacman died! Score: -437
# Pacman died! Score: -451
# Pacman died! Score: -429
# Pacman died! Score: -280
# Pacman died! Score: -432
# Pacman died! Score: -446
# Pacman died! Score: -446
# Pacman died! Score: -446
# Pacman died! Score: -311
# Average Score: -401.7
# Scores:        -339.0, -437.0, -451.0, -429.0, -280.0, -432.0, -446.0, -446.0, -446.0, -311.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# sub
#    add
#       mul
#          minDistEdibleGhost
#          add
#             minDistEdibleGhost
#             1.0
#       mul
#          add
#             1.0
#             minDistEdibleGhost
#          -1.0
#    mul
#       add
#          minDistEdibleGhost
#          add
#             -1.0
#             minGhostDist
#       add
#          add
#             2.0
#             eatFood
#          distToPill
# Pacman died! Score: -428
# Pacman died! Score: -392
# Pacman died! Score: -446
# Pacman died! Score: -428
# Pacman died! Score: -438
# Pacman died! Score: -437
# Pacman died! Score: -428
# Pacman died! Score: -96
# Pacman died! Score: -446
# Pacman died! Score: -446
# Average Score: -398.5
# Scores:        -428.0, -392.0, -446.0, -428.0, -438.0, -437.0, -428.0, -96.0, -446.0, -446.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# sub
#    mul
#       mul
#          mul
#             minDistEdibleGhost
#             actionScore
#          mul
#             distToPill
#             distToPill
#       add
#          -1.0
#          sub
#             minDistEdibleGhost
#             eatFood
#    mul
#       0.5
#       mul
#          distToPill
#          2.0
# Pacman died! Score: -446
# Pacman died! Score: -428
# Pacman died! Score: -446
# Pacman died! Score: -429
# Pacman died! Score: -416
# Pacman died! Score: -343
# Pacman died! Score: -446
# Pacman died! Score: -446
# Pacman died! Score: -446
# Pacman died! Score: -78
# Average Score: -392.4
# Scores:        -446.0, -428.0, -446.0, -429.0, -416.0, -343.0, -446.0, -446.0, -446.0, -78.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# mul
#    add
#       2.0
#       mul
#          mul
#             actionScore
#             eatFood
#          1.0
#    sub
#       add
#          add
#             2.0
#             actionScore
#          minGhostDist
#       mul
#          sub
#             2.0
#             eatFood
#          minDistToFood
# Pacman died! Score: -428
# Pacman died! Score: -267
# Pacman died! Score: -430
# Pacman died! Score: -446
# Pacman died! Score: -429
# Pacman died! Score: -248
# Pacman died! Score: -429
# Pacman died! Score: -429
# Pacman died! Score: -431
# Pacman died! Score: -451
# Average Score: -398.8
# Scores:        -428.0, -267.0, -430.0, -446.0, -429.0, -248.0, -429.0, -429.0, -431.0, -451.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# mul
#    add
#       add
#          2.0
#          distToPill
#       minDistToFood
#    add
#       actionScore
#       mul
#          add
#             0.5
#             1.0
#          add
#             minDistToFood
#             minGhostDist
# Pacman died! Score: -446
# Pacman died! Score: -428
# Pacman died! Score: -429
# Pacman died! Score: -459
# Pacman died! Score: -431
# Pacman died! Score: -446
# Pacman died! Score: -433
# Pacman died! Score: -429
# Pacman died! Score: -431
# Pacman died! Score: -430
# Average Score: -436.2
# Scores:        -446.0, -428.0, -429.0, -459.0, -431.0, -446.0, -433.0, -429.0, -431.0, -430.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# mul
#    mul
#       add
#          add
#             minGhostDist
#             distToPill
#          sub
#             1.0
#             minGhostDist
#       distToPill
#    mul
#       mul
#          2.0
#          sub
#             minDistEdibleGhost
#             minDistToFood
#       sub
#          add
#             0.5
#             actionScore
#          sub
#             2.0
#             minDistEdibleGhost
# Pacman died! Score: -428
# Pacman died! Score: -429
# Pacman died! Score: -430
# Pacman died! Score: -428
# Pacman died! Score: -126
# Pacman died! Score: -428
# Pacman died! Score: -452
# Pacman died! Score: -321
# Pacman died! Score: -428
# Pacman died! Score: -252
# Average Score: -372.2
# Scores:        -428.0, -429.0, -430.0, -428.0, -126.0, -428.0, -452.0, -321.0, -428.0, -252.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    sub
#       2.0
#       sub
#          sub
#             distToPill
#             actionScore
#          -1.0
#    sub
#       minGhostDist
#       mul
#          sub
#             2.0
#             minDistEdibleGhost
#          sub
#             minGhostDist
#             1.0
# Pacman died! Score: -446
# Pacman died! Score: 81
# Pacman died! Score: -430
# Pacman died! Score: -429
# Pacman died! Score: -249
# Pacman died! Score: -434
# Pacman died! Score: -391
# Pacman died! Score: -248
# Pacman died! Score: -430
# Pacman died! Score: 50
# Average Score: -292.6
# Scores:        -446.0, 81.0, -430.0, -429.0, -249.0, -434.0, -391.0, -248.0, -430.0, 50.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    sub
#       add
#          sub
#             actionScore
#             minGhostDist
#          minDistToFood
#       mul
#          sub
#             actionScore
#             2.0
#          add
#             distToPill
#             2.0
#    add
#       1.0
#       -1.0
# Pacman died! Score: -355
# Pacman died! Score: -428
# Pacman died! Score: -429
# Pacman died! Score: -317
# Pacman died! Score: -432
# Pacman died! Score: -430
# Pacman died! Score: -143
# Pacman died! Score: -446
# Pacman died! Score: -430
# Pacman died! Score: -437
# Average Score: -384.7
# Scores:        -355.0, -428.0, -429.0, -317.0, -432.0, -430.0, -143.0, -446.0, -430.0, -437.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    add
#       mul
#          sub
#             distToPill
#             -1.0
#          0.5
#       sub
#          minGhostDist
#          mul
#             2.0
#             distToPill
#    sub
#       actionScore
#       add
#          add
#             distToPill
#             2.0
#          0.5
# Pacman died! Score: -326
# Pacman died! Score: -429
# Pacman died! Score: -353
# Pacman died! Score: -446
# Pacman died! Score: -416
# Pacman died! Score: -354
# Pacman died! Score: -446
# Pacman died! Score: -428
# Pacman died! Score: -187
# Pacman died! Score: -446
# Average Score: -383.1
# Scores:        -326.0, -429.0, -353.0, -446.0, -416.0, -354.0, -446.0, -428.0, -187.0, -446.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# sub
#    mul
#       minGhostDist
#       mul
#          distToPill
#          1.0
#    add
#       2.0
#       0.5
# Pacman died! Score: -214
# Pacman died! Score: -88
# Pacman died! Score: -429
# Pacman died! Score: -446
# Pacman died! Score: -348
# Pacman died! Score: -446
# Pacman died! Score: -430
# Pacman died! Score: -430
# Pacman died! Score: -432
# Pacman died! Score: -437
# Average Score: -370.0
# Scores:        -214.0, -88.0, -429.0, -446.0, -348.0, -446.0, -430.0, -430.0, -432.0, -437.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    mul
#       add
#          minDistEdibleGhost
#          add
#             2.0
#             eatFood
#       sub
#          minDistEdibleGhost
#          mul
#             -1.0
#             minDistEdibleGhost
#    add
#       distToPill
#       sub
#          add
#             actionScore
#             minDistToFood
#          minGhostDist
# Pacman died! Score: -428
# Pacman died! Score: -373
# Pacman died! Score: -432
# Pacman died! Score: -430
# Pacman died! Score: -446
# Pacman died! Score: -324
# Pacman died! Score: -432
# Pacman died! Score: -428
# Pacman died! Score: -406
# Pacman died! Score: -415
# Average Score: -411.4
# Scores:        -428.0, -373.0, -432.0, -430.0, -446.0, -324.0, -432.0, -428.0, -406.0, -415.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# mul
#    sub
#       minGhostDist
#       minDistEdibleGhost
#    sub
#       eatFood
#       sub
#          add
#             minDistToFood
#             distToPill
#          2.0
# Pacman died! Score: -446
# Pacman died! Score: -358
# Pacman died! Score: -446
# Pacman died! Score: -430
# Pacman died! Score: -428
# Pacman died! Score: -429
# Pacman died! Score: -446
# Pacman died! Score: -50
# Pacman died! Score: 120
# Pacman died! Score: -261
# Average Score: -317.4
# Scores:        -446.0, -358.0, -446.0, -430.0, -428.0, -429.0, -446.0, -50.0, 120.0, -261.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# sub
#    mul
#       1.0
#       sub
#          2.0
#          0.5
#    add
#       mul
#          -1.0
#          0.5
#       2.0
# Pacman died! Score: -429
# Pacman died! Score: -274
# Pacman died! Score: -305
# Pacman died! Score: -446
# Pacman died! Score: -430
# Pacman died! Score: -392
# Pacman died! Score: -430
# Pacman died! Score: -446
# Pacman died! Score: -451
# Pacman died! Score: -428
# Average Score: -403.1
# Scores:        -429.0, -274.0, -305.0, -446.0, -430.0, -392.0, -430.0, -446.0, -451.0, -428.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    mul
#       mul
#          sub
#             actionScore
#             -1.0
#          eatFood
#       add
#          sub
#             minDistEdibleGhost
#             0.5
#          mul
#             minDistToFood
#             2.0
#    mul
#       0.5
#       sub
#          sub
#             minGhostDist
#             -1.0
#          mul
#             0.5
#             1.0
# Pacman died! Score: -429
# Pacman died! Score: -428
# Pacman died! Score: -431
# Pacman died! Score: -431
# Pacman died! Score: -228
# Pacman died! Score: -350
# Pacman died! Score: -429
# Pacman died! Score: -372
# Pacman died! Score: -428
# Pacman died! Score: -429
# Average Score: -395.5
# Scores:        -429.0, -428.0, -431.0, -431.0, -228.0, -350.0, -429.0, -372.0, -428.0, -429.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    mul
#       add
#          sub
#             actionScore
#             0.5
#          minGhostDist
#       sub
#          distToPill
#          mul
#             1.0
#             eatFood
#    sub
#       -1.0
#       sub
#          1.0
#          sub
#             distToPill
# ...
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# mul
#    add
#       actionScore
#       1.0
#    mul
#       2.0
#       minDistToFood
# Pacman died! Score: -428
# Pacman died! Score: -430
# Pacman died! Score: -446
# Pacman died! Score: -446
# Pacman died! Score: -446
# Pacman died! Score: -234
# Pacman died! Score: -315
# Pacman died! Score: -428
# Pacman died! Score: -446
# Pacman died! Score: -268
# Average Score: -388.7
# Scores:        -428.0, -430.0, -446.0, -446.0, -446.0, -234.0, -315.0, -428.0, -446.0, -268.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# mul
#    add
#       actionScore
#       1.0
#    mul
#       2.0
#       minDistToFood
# Pacman died! Score: -419
# Pacman died! Score: -82
# Pacman died! Score: -389
# Pacman died! Score: -437
# Pacman died! Score: -438
# Pacman died! Score: -228
# Pacman died! Score: -406
# Pacman died! Score: -446
# Pacman died! Score: -368
# Pacman died! Score: -430
# Average Score: -364.3
# Scores:        -419.0, -82.0, -389.0, -437.0, -438.0, -228.0, -406.0, -446.0, -368.0, -430.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# mul
#    add
#       actionScore
#       1.0
#    mul
#       2.0
#       minDistToFood
# Pacman died! Score: -446
# Pacman died! Score: -446
# Pacman died! Score: 64
# Pacman died! Score: -419
# Pacman died! Score: 40
# Pacman died! Score: -429
# Pacman died! Score: -450
# Pacman died! Score: -430
# Pacman died! Score: -331
# Pacman died! Score: -450
# Average Score: -329.7
# Scores:        -446.0, -446.0, 64.0, -419.0, 40.0, -429.0, -450.0, -430.0, -331.0, -450.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    mul
#       add
#          minDistEdibleGhost
#          minDistEdibleGhost
#       mul
#          minDistToFood
#          1.0
#    add
#       0.5
#       eatFood
# Pacman died! Score: -376
# Pacman died! Score: -430
# Pacman died! Score: -206
# Pacman died! Score: -431
# Pacman died! Score: -446
# Pacman died! Score: -446
# Pacman died! Score: -437
# Pacman died! Score: -446
# Pacman died! Score: -428
# Pacman died! Score: -430
# Average Score: -407.6
# Scores:        -376.0, -430.0, -206.0, -431.0, -446.0, -446.0, -437.0, -446.0, -428.0, -430.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# mul
#    add
#       actionScore
#       1.0
#    mul
#       2.0
#       minDistToFood
# Pacman died! Score: -429
# Pacman died! Score: -429
# Pacman died! Score: -406
# Pacman died! Score: -429
# Pacman died! Score: -430
# Pacman died! Score: -419
# Pacman died! Score: -366
# Pacman died! Score: -446
# Pacman died! Score: -432
# Pacman died! Score: -430
# Average Score: -421.6
# Scores:        -429.0, -429.0, -406.0, -429.0, -430.0, -419.0, -366.0, -446.0, -432.0, -430.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# mul
#    add
#       actionScore
#       1.0
#    mul
#       2.0
#       minDistToFood
# Pacman died! Score: -446
# Pacman died! Score: -348
# Pacman died! Score: -429
# Pacman died! Score: -114
# Pacman died! Score: -428
# Pacman died! Score: -428
# Pacman died! Score: -429
# Pacman died! Score: -428
# Pacman died! Score: -429
# Pacman died! Score: -428
# Average Score: -390.7
# Scores:        -446.0, -348.0, -429.0, -114.0, -428.0, -428.0, -429.0, -428.0, -429.0, -428.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# mul
#    add
#       actionScore
#       1.0
#    mul
#       2.0
#       minDistToFood
# Pacman died! Score: -373
# Pacman died! Score: -428
# Pacman died! Score: -382
# Pacman died! Score: -375
# Pacman died! Score: -446
# Pacman died! Score: -283
# Pacman died! Score: -385
# Pacman died! Score: -446
# Pacman died! Score: -360
# Pacman died! Score: -446
# Average Score: -392.4
# Scores:        -373.0, -428.0, -382.0, -375.0, -446.0, -283.0, -385.0, -446.0, -360.0, -446.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# mul
#    add
#       actionScore
#       1.0
#    mul
#       2.0
#       minDistToFood
# Pacman died! Score: -74
# Pacman died! Score: -252
# Pacman died! Score: -369
# Pacman died! Score: -430
# Pacman died! Score: -450
# Pacman died! Score: -446
# Pacman died! Score: -383
# Pacman died! Score: -428
# Pacman died! Score: -446
# Pacman died! Score: -112
# Average Score: -339.0
# Scores:        -74.0, -252.0, -369.0, -430.0, -450.0, -446.0, -383.0, -428.0, -446.0, -112.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    mul
#       add
#          minDistEdibleGhost
#          minDistEdibleGhost
#       mul
#          minDistToFood
#          1.0
#    add
#       0.5
#       eatFood
# Pacman died! Score: -429
# Pacman died! Score: -429
# Pacman died! Score: -429
# Pacman died! Score: -271
# Pacman died! Score: -437
# Pacman died! Score: -107
# Pacman died! Score: -437
# Pacman died! Score: -428
# Pacman died! Score: -374
# Pacman died! Score: -446
# Average Score: -378.7
# Scores:        -429.0, -429.0, -429.0, -271.0, -437.0, -107.0, -437.0, -428.0, -374.0, -446.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# mul
#    add
#       actionScore
#       1.0
#    mul
#       2.0
#       minDistToFood
# Pacman died! Score: -431
# Pacman died! Score: -302
# Pacman died! Score: -446
# Pacman died! Score: -446
# Pacman died! Score: -429
# Pacman died! Score: -225
# Pacman died! Score: -387
# Pacman died! Score: -429
# Pacman died! Score: -451
# Pacman died! Score: -430
# Average Score: -397.6
# Scores:        -431.0, -302.0, -446.0, -446.0, -429.0, -225.0, -387.0, -429.0, -451.0, -430.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    mul
#       add
#          minDistEdibleGhost
#          minDistEdibleGhost
#       mul
#          minDistToFood
#          1.0
#    add
#       0.5
#       eatFood
# Pacman died! Score: -428
# Pacman died! Score: -429
# Pacman died! Score: -429
# Pacman died! Score: -446
# Pacman died! Score: -428
# Pacman died! Score: -430
# Pacman died! Score: -446
# Pacman died! Score: -437
# Pacman died! Score: -416
# Pacman died! Score: -351
# Average Score: -424.0
# Scores:        -428.0, -429.0, -429.0, -446.0, -428.0, -430.0, -446.0, -437.0, -416.0, -351.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    mul
#       add
#          minDistEdibleGhost
#          minDistEdibleGhost
#       mul
#          minDistToFood
#          1.0
#    add
#       0.5
#       eatFood
# Pacman died! Score: -446
# Pacman died! Score: -446
# Pacman died! Score: -308
# Pacman died! Score: -429
# Pacman died! Score: -189
# Pacman died! Score: -330
# Pacman died! Score: -446
# Pacman died! Score: -203
# Pacman died! Score: -446
# Pacman died! Score: -429
# Average Score: -367.2
# Scores:        -446.0, -446.0, -308.0, -429.0, -189.0, -330.0, -446.0, -203.0, -446.0, -429.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# mul
#    add
#       actionScore
#       1.0
#    mul
#       2.0
#       minDistToFood
# Pacman died! Score: -430
# Pacman died! Score: -428
# Pacman died! Score: -356
# Pacman died! Score: -357
# Pacman died! Score: -258
# Pacman died! Score: -446
# Pacman died! Score: -446
# Pacman died! Score: -429
# Pacman died! Score: -446
# Pacman died! Score: -428
# Average Score: -402.4
# Scores:        -430.0, -428.0, -356.0, -357.0, -258.0, -446.0, -446.0, -429.0, -446.0, -428.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# mul
#    add
#       actionScore
#       1.0
#    mul
#       2.0
#       minDistToFood
# Pacman died! Score: -438
# Pacman died! Score: -429
# Pacman died! Score: -437
# Pacman died! Score: -430
# Pacman died! Score: -242
# Pacman died! Score: -350
# Pacman died! Score: -316
# Pacman died! Score: -227
# Pacman died! Score: -446
# Pacman died! Score: -429
# Average Score: -374.4
# Scores:        -438.0, -429.0, -437.0, -430.0, -242.0, -350.0, -316.0, -227.0, -446.0, -429.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    mul
#       add
#          minDistEdibleGhost
#          minDistEdibleGhost
#       mul
#          minDistToFood
#          1.0
#    add
#       0.5
#       eatFood
# Pacman died! Score: -446
# Pacman died! Score: -429
# Pacman died! Score: -446
# Pacman died! Score: -364
# Pacman died! Score: -446
# Pacman died! Score: -432
# Pacman died! Score: -427
# Pacman died! Score: -430
# Pacman died! Score: -430
# Pacman died! Score: -432
# Average Score: -428.2
# Scores:        -446.0, -429.0, -446.0, -364.0, -446.0, -432.0, -427.0, -430.0, -430.0, -432.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    mul
#       add
#          minDistEdibleGhost
#          minDistEdibleGhost
#       mul
#          minDistToFood
#          1.0
#    add
#       0.5
#       eatFood
# Pacman died! Score: -334
# Pacman died! Score: -326
# Pacman died! Score: -351
# Pacman died! Score: -428
# Pacman died! Score: -446
# Pacman died! Score: -437
# Pacman died! Score: -429
# Pacman died! Score: -243
# Pacman died! Score: -446
# Pacman died! Score: -251
# Average Score: -369.1
# Scores:        -334.0, -326.0, -351.0, -428.0, -446.0, -437.0, -429.0, -243.0, -446.0, -251.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    mul
#       add
#          minDistEdibleGhost
#          minDistEdibleGhost
#       mul
#          minDistToFood
#          1.0
#    add
#       0.5
#       eatFood
# Pacman died! Score: -376
# Pacman died! Score: -437
# Pacman died! Score: -245
# Pacman died! Score: -431
# Pacman died! Score: -431
# Pacman died! Score: -428
# Pacman died! Score: -446
# Pacman died! Score: -428
# Pacman died! Score: -437
# Pacman died! Score: -428
# Average Score: -408.7
# Scores:        -376.0, -437.0, -245.0, -431.0, -431.0, -428.0, -446.0, -428.0, -437.0, -428.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    mul
#       add
#          minDistEdibleGhost
#          minDistEdibleGhost
#       mul
#          minDistToFood
#          1.0
#    add
#       0.5
#       eatFood
# Pacman died! Score: -429
# Pacman died! Score: -391
# Pacman died! Score: 36
# Pacman died! Score: -338
# Pacman died! Score: -446
# Pacman died! Score: -437
# Pacman died! Score: -323
# Pacman died! Score: -330
# Pacman died! Score: -429
# Pacman died! Score: -446
# Average Score: -353.3
# Scores:        -429.0, -391.0, 36.0, -338.0, -446.0, -437.0, -323.0, -330.0, -429.0, -446.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    mul
#       add
#          minDistEdibleGhost
#          minDistEdibleGhost
#       mul
#          minDistToFood
#          1.0
#    add
#       0.5
#       eatFood
# Pacman died! Score: -383
# Pacman died! Score: -338
# Pacman died! Score: -356
# Pacman died! Score: -429
# Pacman died! Score: -420
# Pacman died! Score: -29
# Pacman died! Score: -428
# Pacman died! Score: -428
# Pacman died! Score: -236
# Pacman died! Score: -318
# Average Score: -336.5
# Scores:        -383.0, -338.0, -356.0, -429.0, -420.0, -29.0, -428.0, -428.0, -236.0, -318.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    mul
#       add
#          minDistEdibleGhost
#          minDistEdibleGhost
#       mul
#          minDistToFood
#          1.0
#    add
#       0.5
#       eatFood
# Pacman died! Score: -446
# Pacman died! Score: -437
# Pacman died! Score: -428
# Pacman died! Score: -446
# Pacman died! Score: -375
# Pacman died! Score: -429
# Pacman died! Score: -446
# Pacman died! Score: 260
# Pacman died! Score: -428
# Pacman died! Score: -430
# Average Score: -360.5
# Scores:        -446.0, -437.0, -428.0, -446.0, -375.0, -429.0, -446.0, 260.0, -428.0, -430.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    mul
#       add
#          minDistEdibleGhost
#          minDistEdibleGhost
#       mul
#          minDistToFood
#          1.0
#    add
#       0.5
#       eatFood
# Pacman died! Score: -430
# Pacman died! Score: -206
# Pacman died! Score: -429
# Pacman died! Score: -428
# Pacman died! Score: -446
# Pacman died! Score: -446
# Pacman died! Score: -446
# Pacman died! Score: -429
# Pacman died! Score: -437
# Pacman died! Score: -389
# Average Score: -408.6
# Scores:        -430.0, -206.0, -429.0, -428.0, -446.0, -446.0, -446.0, -429.0, -437.0, -389.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# mul
#    add
#       actionScore
#       1.0
#    mul
#       2.0
#       minDistToFood
# Pacman died! Score: -429
# Pacman died! Score: -446
# Pacman died! Score: -446
# Pacman died! Score: -102
# Pacman died! Score: -428
# Pacman died! Score: -446
# Pacman died! Score: 139
# Pacman died! Score: -430
# Pacman died! Score: -283
# Pacman died! Score: -431
# Average Score: -330.2
# Scores:        -429.0, -446.0, -446.0, -102.0, -428.0, -446.0, 139.0, -430.0, -283.0, -431.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    mul
#       add
#          minDistEdibleGhost
#          minDistEdibleGhost
#       mul
#          minDistToFood
#          1.0
#    add
#       0.5
#       eatFood
# Pacman died! Score: -457
# Pacman died! Score: -212
# Pacman died! Score: -383
# Pacman died! Score: -383
# Pacman died! Score: -431
# Pacman died! Score: -446
# Pacman died! Score: -339
# Pacman died! Score: -432
# Pacman died! Score: -446
# Pacman died! Score: -419
# Average Score: -394.8
# Scores:        -457.0, -212.0, -383.0, -383.0, -431.0, -446.0, -339.0, -432.0, -446.0, -419.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss
# layout:  smallClassic
# ------------------------------------------ train --------------------
# add
#    mul
#       add
#          minDistEdibleGhost
#          minDistEdibleGhost
#       mul
#          minDistToFood
#          1.0
#    add
#       0.5
#       eatFood
# Pacman died! Score: -218
# Pacman died! Score: -429
# Pacman died! Score: -444
# Pacman died! Score: -429

# %%
# args = readCommand(['--layout', 'smallClassic', '--pacman', 'GoWestAgent', '-t']) # Get game components based on input
gameLayout = layout.getLayout( 'smallClassic' )

ind = GPTree()
ind.random_tree(True, 2)
ind.print_tree()

pacman = MyGoWestAgent(ind)
# pacman.setTree(ind)

ghostType = loadAgent('RandomGhost', True)
ghosts = [ghostType( i+1 ) for i in range( 4 )]

import textDisplay
textDisplay.SLEEP_TIME = 0.1
gameDisplay = textDisplay.PacmanGraphics()

runGames(gameLayout, pacman, ghosts, gameDisplay, 3, False)
